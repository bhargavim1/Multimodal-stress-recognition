# %%
for i in range(1,17):
    p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==i)]
    p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

    p1_cog = frame[(frame['Subject']==1) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
    p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
    p1_cog = p1_cog-p1_norm.mean()
    filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
    plt.figure(num=None, figsize=(7, 4), dpi=80, facecolor='w', edgecolor='k')
    filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
    plt.title('Cognitive stress response feature plot for subject '+ str(i))
    plt.xlabel('Physiological responses')


    plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
import csv

# %%
import pandas

# %%
T001= pandas.read_csv('T001.csv')

# %%
T001

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=T001)

# %%
df.loc[df['Failure']== 6]

# %%
T003= pd.read_csv('T004.csv')

# %%
T003= pd.read_csv('T004.csv')
df3 = pd.DataFrame(data=T003)

# %%
import numpy as np
m=np.mean(df3.loc[df3['Drive']==2]['Heart.Rate'])
v=np.var(df3.loc[df3['Drive']==2]['Heart.Rate'])
df3[(df3['Stimulus']==0) | (df3['Drive']==8)]

# %%
import matplotlib.pyplot as plt
rd=df3.loc[df3['Drive']==2]
pd=df3.loc[df3['Drive']==3]
nd=df3.loc[df3['Drive']==4]
df3[(df3['Stimulus']==0) | (df3['Drive']==8)]
cd=df3[(df3['Drive']==5)&((df3['Stimulus']==1)|(df3['Stimulus']==2))]
ed=df3[(df3['Drive']==6)&((df3['Stimulus']==3)|(df3['Stimulus']==3))]
md=df3[(df3['Drive']==7)&((df3['Stimulus']==4)|(df3['Stimulus']==4))]
fd=df3[df3['Failure']==6]
plt.subplot(331)
plt.title('rd')
rd.boxplot(column='Heart.Rate',return_type='axes',figsize=(40,20))

plt.subplot(332)
plt.title('pd')
pd.boxplot(column='Heart.Rate', figsize=(20,10))

plt.subplot(333)
plt.title('nd')
nd.boxplot(column='Heart.Rate',figsize=(20,10),)

plt.subplot(334)
plt.title('cd')
cd.boxplot(column='Heart.Rate')
plt.subplot(335)
plt.title('ed')
ed.boxplot(column='Heart.Rate')
plt.subplot(336)
plt.title('md')
md.boxplot(column='Heart.Rate')
plt.subplot(337)
plt.title('fd')
fd.boxplot(column='Heart.Rate')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
T003= pd.read_csv('T003.csv')
df3 = pd.DataFrame(data=T003)
rd=df3.loc[df3['Drive']==2]
pd=df3.loc[df3['Drive']==3]
nd=df3.loc[df3['Drive']==4]
df3[(df3['Stimulus']==0) | (df3['Drive']==8)]
cd=df3[(df3['Drive']==5)&((df3['Stimulus']==1)|(df3['Stimulus']==2))]
ed=df3[(df3['Drive']==6)&((df3['Stimulus']==3)|(df3['Stimulus']==3))]
md=df3[(df3['Drive']==7)&((df3['Stimulus']==4)|(df3['Stimulus']==4))]
fd=df3[df3['Failure']==6]
plt.subplot(331)
plt.title('rd')
rd.boxplot(column='Heart.Rate',return_type='axes',figsize=(20,10))

plt.subplot(332)
plt.title('pd')
pd.boxplot(column='Heart.Rate', figsize=(20,10))

plt.subplot(333)
plt.title('nd')
nd.boxplot(column='Heart.Rate',figsize=(20,10),)

plt.subplot(334)
plt.title('cd')
cd.boxplot(column='Heart.Rate')
plt.subplot(335)
plt.title('ed')
ed.boxplot(column='Heart.Rate')
plt.subplot(336)
plt.title('md')
md.boxplot(column='Heart.Rate')
plt.subplot(337)
plt.title('fd')
fd.boxplot(column='Heart.Rate')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
T003= pd.read_csv('T006.csv')
df3 = pd.DataFrame(data=T003)
rd=df3.loc[df3['Drive']==2]
pd=df3.loc[df3['Drive']==3]
nd=df3.loc[df3['Drive']==4]
df3[(df3['Stimulus']==0) | (df3['Drive']==8)]
cd=df3[(df3['Drive']==5)&((df3['Stimulus']==1)|(df3['Stimulus']==2))]
ed=df3[(df3['Drive']==6)&((df3['Stimulus']==3)|(df3['Stimulus']==3))]
md=df3[(df3['Drive']==7)&((df3['Stimulus']==4)|(df3['Stimulus']==4))]
fd=df3[df3['Failure']==6]
plt.subplot(331)
plt.title('rd')
rd.boxplot(column='Heart.Rate',return_type='axes',figsize=(20,10))

plt.subplot(332)
plt.title('pd')
pd.boxplot(column='Heart.Rate', figsize=(20,10))

plt.subplot(333)
plt.title('nd')
nd.boxplot(column='Heart.Rate',figsize=(20,10),)

plt.subplot(334)
plt.title('cd')
cd.boxplot(column='Heart.Rate')
plt.subplot(335)
plt.title('ed')
ed.boxplot(column='Heart.Rate')
plt.subplot(336)
plt.title('md')
md.boxplot(column='Heart.Rate')
plt.subplot(337)
plt.title('fd')
fd.boxplot(column='Heart.Rate')
plt.show()

# %%
T002

# %%
import matplotlib.pyplot as plt
import pandas as pd
T003= pd.read_csv('T007.csv')
df3 = pd.DataFrame(data=T003)
rd=df3.loc[df3['Drive']==2]['Heart.Rate']
p_d=df3.loc[df3['Drive']==3]['Heart.Rate']
nd=df3.loc[df3['Drive']==4]['Heart.Rate']
cd=df3[(df3['Drive']==5)&((df3['Stimulus']==1)|(df3['Stimulus']==2))]['Heart.Rate']
ed=df3[(df3['Drive']==6)&((df3['Stimulus']==3)|(df3['Stimulus']==3))]['Heart.Rate']
md=df3[(df3['Drive']==7)&((df3['Stimulus']==4)|(df3['Stimulus']==4))]['Heart.Rate']
fd=df3[df3['Failure']==6]['Heart.Rate']


ct = pd.concat([rd, p_d,nd,cd,ed,md,fd], axis=1)

# %%
ct.boxplot()
labels = ['rd','pd']
_=plt.xticks(range(1,3),labels)
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':

# %%
import glob
path = r'/home/bhargavi/Dropbox/LEA/R_D/Version4/Revised_report/data/SimDriv/Multimodal-stress-recognition'
allFiles = glob.glob(path+"/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

# %% [markdown]
# # normal.mean()

# %%
cognitive.mean()
# Out:
# Time                        344.977515
# Drive                         5.000000
# Stimulus                      1.499680
# Failure                       0.000000
# Palm.EDA                  10202.222157
# Heart.Rate                   75.658193
# Breathing.Rate               16.430106
# Perinasal.Perspiration        0.006413
# Speed                        73.936211
# Acceleration                  6.775457
# Brake                         9.576058
# Steering                      0.000207
# LaneOffset                   -0.074147
# Lane.Position                 1.907984
# Distance                   5335.787215
# Gaze.X.Pos                  602.234024
# Gaze.Y.Pos                  582.228225
# Lft.Pupil.Diameter            0.003157
# Rt.Pupil.Diameter             0.003332
# Subject                      29.663800
# dtype: float64

# %%
frame
# Out:
#       Time  Drive  Stimulus  Failure  Palm.EDA  Heart.Rate  Breathing.Rate  \
# 0        1      1         0        0       NaN         NaN             NaN
# 1        2      1         0        0       NaN         NaN             NaN
# 2        3      1         0        0       NaN         NaN             NaN
# 3        4      1         0        0       NaN         NaN             NaN
# 4        5      1         0        0       NaN         NaN             NaN
# 5        6      1         0        0       NaN         NaN             NaN
# 6        7      1         0        0       NaN         NaN             NaN
# 7        8      1         0        0       NaN         NaN             NaN
# 8        9      1         0        0       NaN         NaN             NaN
# 9       10      1         0        0       NaN         NaN             NaN
# 10      11      1         0        0       NaN         NaN             NaN
# ...

# %%
relax=frame.loc[frame['Drive']==2]
practice=frame.loc[frame['Drive']==3]
normal=frame.loc[frame['Drive']==4]
cognitive=frame[(frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
emotional=frame[(frame['Drive']==6)&((frame['Stimulus']==3)|(frame['Stimulus']==3))]
sensorimotor=frame[(frame['Drive']==7)&((frame['Stimulus']==4)|(frame['Stimulus']==4))]
failure_nl=frame[(frame['Failure']==6)&(frame['Stimulus']==0)]
failure_l=frame[(frame['Failure']==6)&(frame['Stimulus']==5)]

norm_normz = (normal-normal.min())/(normal.max()-normal.min())
norm_normz.mean()
sens_normz = (sensorimotor-sensorimotor.min())/(sensorimotor.max()-sensorimotor.min())
sens_normz-norm_normz.mean()
# Out:
#           Time  Drive  Stimulus  Failure  Palm.EDA  Heart.Rate  \
# 3807 -0.381823    NaN       NaN      NaN -0.218544   -0.055971
# 3808 -0.380361    NaN       NaN      NaN -0.218540   -0.039022
# 3809 -0.378899    NaN       NaN      NaN -0.218538   -0.022072
# 3810 -0.377437    NaN       NaN      NaN -0.218545   -0.039022
# 3811 -0.375975    NaN       NaN      NaN -0.218582   -0.055971
# 3812 -0.374513    NaN       NaN      NaN -0.218605   -0.072920
# 3813 -0.373051    NaN       NaN      NaN -0.218613   -0.106818
# 3814 -0.371589    NaN       NaN      NaN -0.218628   -0.106818
# 3815 -0.370127    NaN       NaN      NaN -0.218626   -0.089869
# 3816 -0.368665    NaN       NaN      NaN -0.218625   -0.123767
# 3817 -0.367203    NaN       NaN      NaN -0.218624   -0.089869
# 3818 -0.365741    NaN       NaN      NaN -0.218617   -0.055971
# 3819 -0.364279    NaN       NaN      NaN -0.218625   -0.072920
# 3820 -0.362817    NaN       NaN      NaN -0.218619   -0.123767
# ...

# %%
#fig, ax = plt.subplots(figsize=(10,  10))
normal_normz = (normal-normal.min())/(normal.max()-normal.min())
zero_mean_cog = (normal_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
filtered_cog.boxplot( showmeans=True,showfliers=True)
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

plt.show()
sens_normz = (cognitive-cognitive.min())/(cognitive.max()-cognitive.min())
zero_mean_cog = (sens_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

filtered_cog.boxplot( showmeans=True,showfliers=True, )
plt.show()
sens_normz = (sensorimotor-sensorimotor.min())/(sensorimotor.max()-sensorimotor.min())
zero_mean_cog = (sens_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
filtered_cog.boxplot( showmeans=True,showfliers=True,)
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

plt.show()
sens_normz = (emotional-emotional.min())/(emotional.max()-emotional.min())
zero_mean_cog = (sens_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
filtered_cog.boxplot( showmeans=True,showfliers=True,)
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

plt.show()


sens_normz = (failure_nl-failure_nl.min())/(failure_nl.max()-failure_nl.min())
zero_mean_cog = (sens_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

filtered_cog.boxplot( showmeans=True,showfliers=True, )
plt.show()



sens_normz = (failure_l-failure_l.min())/(failure_l.max()-failure_l.min())
zero_mean_cog = (sens_normz -normal_normz.mean())
filtered_cog = zero_mean_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(7, 5), dpi=80, facecolor='w', edgecolor='k')
plt.xlabel('Modalities')
plt.ylabel('Normalized change in resposes from mean baseline')

filtered_cog.boxplot( showmeans=True,showfliers=True, )
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:18: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
# ...

# %%
zero_mean_cog = (cognitive -normal.mean())/normal.mean()
filtered_cog = zero_mean_cog.loc[:,'Heart.Rate':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
filtered_cog.boxplot( showmeans=True,showfliers=True)
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
frame
# Out:
#        Time  Stimulus  Failure   Palm.EDA  Heart.Rate  Breathing.Rate  \
# Drive
# 1         1         0        0        NaN         NaN             NaN
# 1         2         0        0        NaN         NaN             NaN
# 1         3         0        0        NaN         NaN             NaN
# 1         4         0        0        NaN         NaN             NaN
# 1         5         0        0        NaN         NaN             NaN
# 1         6         0        0        NaN         NaN             NaN
# 1         7         0        0        NaN         NaN             NaN
# 1         8         0        0        NaN         NaN             NaN
# 1         9         0        0        NaN         NaN             NaN
# 1        10         0        0        NaN         NaN             NaN
# 1        11         0        0        NaN         NaN             NaN
# 1        12         0        0        NaN         NaN             NaN
# ...

# %%
[1]*5
# Out:
# [1, 1, 1, 1, 1]

# %%
import glob
path = r'/home/bhargavi/Dropbox/LEA/R_D/Version4/Revised_report/data/SimDriv/Multimodal-stress-recognition'
allFiles = glob.glob(path+"/*.csv")
frame = pd.DataFrame()
Mean_frame = pd.DataFrame()
list_ = []
i=0
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    df['Subject'] = pd.Series([i]*len(df['Time']), index=df.index)
    list_.append(df)
    i+=1
frame = pd.concat(list_)

# %%
relax=frame.loc[frame['Drive']==2]
practice=frame.loc[frame['Drive']==3]
normal=frame.loc[frame['Drive']==4]
cognitive=frame[(frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
emotional=frame[(frame['Drive']==6)&((frame['Stimulus']==3)|(frame['Stimulus']==3))]
sensorimotor=frame[(frame['Drive']==7)&((frame['Stimulus']==4)|(frame['Stimulus']==4))]
failure=frame[frame['Failure']==6]


for i in range(0,60):
    personData = frame[(frame['Subject']== i)]
    relax=personData.loc[personData['Drive']==2]
    practice=personData.loc[personData['Drive']==3]
    normal=personData.loc[personData['Drive']==4]
    cognitive=personData[(personData['Drive']==5)&((personData['Stimulus']==1)|(personData['Stimulus']==2))]
    emotional=personData[(personData['Drive']==6)&((personData['Stimulus']==3)|(personData['Stimulus']==3))]
    sensorimotor=personData[(personData['Drive']==7)&((personData['Stimulus']==4)|(personData['Stimulus']==4))]
    failure=personData[personData['Failure']==6]
    
    df['Subject'] = pd.Series([i]*len(df['Time']), index=df.index)
    list_.append(df)
    i+=1
frame = pd.concat(list_)

# %%
import glob
path = r'/home/bhargavi/Dropbox/LEA/R_D/Version4/Revised_report/data/SimDriv/Multimodal-stress-recognition'
allFiles = glob.glob(path+"/*.csv")
frame = pd.DataFrame()
Mean_frame = pd.DataFrame()
list_ = []
i=0
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    df['Subject'] = pd.Series([i]*len(df['Time']), index=df.index)
    list_.append(df)
    i+=1
frame = pd.concat(list_)

list_n = []
list_c = []
for i in range(0,60):
    personData = frame[(frame['Subject']== i)]
    #relax_mean=personData.loc[personData['Drive']==2].mean()
    #practice_mean=personData.loc[personData['Drive']==3].mean()
    normal_mean=personData.loc[personData['Drive']==4].mean()
    cognitive_mean=personData[(personData['Drive']==5)&((personData['Stimulus']==1)|(personData['Stimulus']==2))].mean()
    #emotional_mean=personData[(personData['Drive']==6)&((personData['Stimulus']==3)|(personData['Stimulus']==3))].mean()
    #sensorimotor_mean=personData[(personData['Drive']==7)&((personData['Stimulus']==4)|(personData['Stimulus']==4))].mean()
    #failure_mean=personData[personData['Failure']==6].mean()
    

    list_n.append(normal_mean)
    list_c.append(cognitive_mean)
new_frame_n= pd.concat(list_n,axis=1)
new_frame_c= pd.concat(list_c,axis=1)
#new_frame_c
new_frame_c = new_frame_c.loc[:,'0':'41']
new_frame_n = new_frame_n.loc[:,'0':'41']

# %%
diff = (new_frame_c-new_frame_n)/new_frame_n*100
diff.sort()
diff = diff.transpose()
diff=diff.sort(['Heart.Rate'])
diff = pd.DataFrame(diff.loc[:,'Heart.Rate':'Perinasal.Perspiration'])

diff.plot( figsize=(20,10),use_index=False)
plt.legend(loc=10, bbox_to_anchor=(0.9, 0.91))
plt.xticks(range(1,42))
plt.grid()
plt.ylabel('Percentage of change ')
plt.xlabel('Person ID')
plt.title('Comparison of changes in physiological responses of individuals under cognitive stress')
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   from ipykernel import kernelapp as app
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
for i in range(1,17):
    p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==i)]
    p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

    p1_cog = frame[(frame['Subject']==1) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
    p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
    p1_cog = p1_cog-p1_norm.mean()
    filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
    plt.figure(num=None, figsize=(7, 4), dpi=80, facecolor='w', edgecolor='k')
    filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
    plt.title('Cognitive stress response feature plot for subject '+ str(i))
    plt.xlabel('Physiological responses')


    plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
for i in range(1,15):
    p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==1) ]
    p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

    p1_cog = frame[(frame['Subject']==2) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
    p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
    p1_cog = p1_cog-p1_norm.mean()
    filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
    plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
    filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
    plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==3) ]
p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

p1_cog = frame[(frame['Subject']==4) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
p1_cog = p1_cog-p1_norm.mean()
filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==4) ]
p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

p1_cog = frame[(frame['Subject']==4) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
p1_cog = p1_cog-p1_norm.mean()
filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
p1_norm=frame[(frame['Drive']==4)&(frame['Subject']==5) ]
p1_norm = (p1_norm-p1_norm.min())/(p1_norm.max()-p1_norm.min())

p1_cog = frame[(frame['Subject']==5) & (frame['Drive']==5)&((frame['Stimulus']==1)|(frame['Stimulus']==2))]
p1_cog = (p1_cog-p1_cog.min())/(p1_cog.max()-p1_cog.min())
p1_cog = p1_cog-p1_norm.mean()
filtered_p1_cog = p1_cog.loc[:,'Palm.EDA':'Perinasal.Perspiration']
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
filtered_p1_cog.boxplot( showmeans=True,showfliers=True)
plt.show()
# Out:
# /home/bhargavi/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
